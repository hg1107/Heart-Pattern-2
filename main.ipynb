# %%
import math
from turtle import *
def hearta(k):
    return 15 * math.sin(k) ** 3
def heartb(k):
    return 13 * math.cos(k) - 5 * math.cos(2 * k) - 2 * math.cos(3 * k) - math.cos(4 * k)
speed(0)
bgcolor('black')
for i in range(6000):
    goto(hearta(i) * 20, heartb(i) * 20)
    for j in range(1):
        color('red')
    dot()
goto(0,0)
done()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# Cell In[1], line 10
#       8 bgcolor('black')
#       9 for i in range(6000):
# ---> 10     goto(hearta(i) * 20, heartb(i) * 20)
#      11     for j in range(1):
#      12         color('red')
#
# File <string>:5, in goto(x, y)
#
# Terminator:
